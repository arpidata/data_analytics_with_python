# %%
import pandas as pd

# %%
# %pip install matplotlib
# Out:
# ...
#    ---------------------------------------- 0.0/8.2 MB ? eta -:--:--
#    --- ------------------------------------ 0.8/8.2 MB 6.5 MB/s eta 0:00:02
#    --------------------- ------------------ 4.5/8.2 MB 14.9 MB/s eta 0:00:01
#    ---------------------------------------  8.1/8.2 MB 17.5 MB/s eta 0:00:01
#    ---------------------------------------- 8.2/8.2 MB 14.6 MB/s  0:00:00
# ...
#    ---------------------------------------- 0.0/2.3 MB ? eta -:--:--
#    ---------------------------------------- 2.3/2.3 MB 25.4 MB/s  0:00:00
# ...
#    ---------------------------------------- 0.0/7.1 MB ? eta -:--:--
#    ---------------------------------------  7.1/7.1 MB 42.1 MB/s eta 0:00:01
#    ---------------------------------------- 7.1/7.1 MB 28.3 MB/s  0:00:00
# ...
#
#    ---------------------------------------- 0/7 [pyparsing]
#    ---------------------------------------- 0/7 [pyparsing]
#    ----- ---------------------------------- 1/7 [pillow]
#    ----- ---------------------------------- 1/7 [pillow]
# ...

# %%
import matplotlib.pyplot as plt
