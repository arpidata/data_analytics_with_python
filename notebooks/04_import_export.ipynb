# %%
import pandas as pd

# %%
df_orders = pd.read_csv('../data/raw/orders.csv')

print(df_orders.columns)
print(df_orders.shape)
df_orders.head(10)
# Out:
# Index(['order_id', 'user_id', 'eval_set', 'order_number', 'order_dow',
#        'order_hour_of_day', 'days_since_prior_order'],
#       dtype='str')
# (3421083, 7)
#    order_id  user_id eval_set  order_number  order_dow  order_hour_of_day  \
# 0   2539329        1    prior             1          2                  8
# 1   2398795        1    prior             2          3                  7
# 2    473747        1    prior             3          3                 12
# 3   2254736        1    prior             4          4                  7
# 4    431534        1    prior             5          4                 15
# 5   3367565        1    prior             6          2                  7
# 6    550135        1    prior             7          1                  9
# 7   3108588        1    prior             8          1                 14
# 8   2295261        1    prior             9          1                 16
# 9   2550362        1    prior            10          4                  8
#
#    days_since_prior_order
# 0                     NaN
# 1                    15.0
# 2                    21.0
# 3                    29.0
# 4                    28.0
# 5                    19.0
# 6                    20.0
# 7                    14.0
# 8                     0.0
# 9                    30.0

# %%
# Reading data
df_orders_products_train = pd.read_csv('../data/raw/order_products_train.csv')
print(df_orders_products_train.columns)
print(df_orders_products_train.shape)
df_orders_products_train.head()
# Out:
# Index(['order_id', 'product_id', 'add_to_cart_order', 'reordered'], dtype='str')
# (1384617, 4)
#    order_id  product_id  add_to_cart_order  reordered
# 0         1       49302                  1          1
# 1         1       11109                  2          1
# 2         1       10246                  3          0
# 3         1       49683                  4          0
# 4         1       43633                  5          1

# %%
df_products = pd.read_csv("../data/raw/products.csv")
df_products.head()
# Out:
#    product_id                                       product_name  aisle_id  \
# 0           1                         Chocolate Sandwich Cookies        61
# 1           2                                   All-Seasons Salt       104
# 2           3               Robust Golden Unsweetened Oolong Tea        94
# 3           4  Smart Ones Classic Favorites Mini Rigatoni Wit...        38
# 4           5                          Green Chile Anytime Sauce         5
#
#    department_id  prices
# 0             19     5.8
# 1             13     9.3
# 2              7     4.5
# 3              1    10.5
# 4             13     4.3

# %%
df_departments = pd.read_csv('../data/processed/departments_t.csv')
print(df_departments.columns)
print(df_departments.shape)
df_departments.head()
# Out:
# Index(['department_id', 'department'], dtype='str')
# (21, 2)
#    department_id department
# 0              0     frozen
# 1              1      other
# 2              2     bakery
# 3              3    produce
# 4              4    alcohol

# %%
df_departments = pd.read_csv('../data/processed/departments_t.csv')
print(df_departments.head())
# Out:
#    department_id department
# 0              0     frozen
# 1              1      other
# 2              2     bakery
# 3              3    produce
# 4              4    alcohol

# %%
df_departments = df_departments.reset_index()
print(df_departments.shape)
# Out:
# (21, 3)

# %%
df_departments = df_departments.reset_index()

# %%
print(df_departments.columns)
# Out:
# Index(['level_0', 'index', 'department_id', 'department'], dtype='str')

# %%
if df_departments.shape[1] == 1:
    df_departments = df_departments.reset_index()

print(df_departments.columns)
print(df_departments.shape)
# Out:
# Index(['level_0', 'index', 'department_id', 'department'], dtype='str')
# (21, 4)

# %%
df_departments = pd.read_csv('../data/processed/departments_t.csv')
print(df_departments.columns)
print(df_departments.shape)
df_departments.head()
# Out:
# Index(['department_id', 'department'], dtype='str')
# (21, 2)
#    department_id department
# 0              0     frozen
# 1              1      other
# 2              2     bakery
# 3              3    produce
# 4              4    alcohol

# %%
if df_departments.shape[1] == 1:
    df_departments = df_departments.reset_index()

# %%
df_departments.rename(columns={'index': 'department_id'}, inplace=True)

# %%
print(df_departments.columns)
print(df_departments.shape)
# Out:
# Index(['department_id', 'department'], dtype='str')
# (21, 2)

# %%
df_departments = df_departments.reset_index()

# %%
df_departments.rename(columns={'index': 'department_id'}, inplace=True)

# %%
df_departments.to_csv('../data/processed/departments_t.csv', index=False)

# %%
df_departments = pd.read_csv('../data/processed/departments_t.csv')
print(df_departments.columns)
print(df_departments.shape)
df_departments.head()
# Out:
# Index(['department_id', 'department_id.1', 'department'], dtype='str')
# (21, 3)
#    department_id  department_id.1 department
# 0              0                0     frozen
# 1              1                1      other
# 2              2                2     bakery
# 3              3                3    produce
# 4              4                4    alcohol

# %%
df_aisles = pd.read_csv('../data/raw/aisles.csv')
print(df_aisles.columns)
print(df_aisles.shape)
df_aisles.head()
# Out:
# Index(['aisle_id', 'aisle'], dtype='str')
# (134, 2)
#    aisle_id                       aisle
# 0         1       prepared soups salads
# 1         2           specialty cheeses
# 2         3         energy granola bars
# 3         4               instant foods
# 4         5  marinades meat preparation

# %%
df_orders.head()
# Out:
#    order_id  user_id eval_set  order_number  order_dow  order_hour_of_day  \
# 0   2539329        1    prior             1          2                  8
# 1   2398795        1    prior             2          3                  7
# 2    473747        1    prior             3          3                 12
# 3   2254736        1    prior             4          4                  7
# 4    431534        1    prior             5          4                 15
#
#    days_since_prior_order
# 0                     NaN
# 1                    15.0
# 2                    21.0
# 3                    29.0
# 4                    28.0

# %%
df_orders.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 3421083 entries, 0 to 3421082
# Data columns (total 7 columns):
#  #   Column                  Dtype
# ---  ------                  -----
#  0   order_id                int64
#  1   user_id                 int64
#  2   eval_set                str
#  3   order_number            int64
#  4   order_dow               int64
#  5   order_hour_of_day       int64
#  6   days_since_prior_order  float64
# dtypes: float64(1), int64(5), str(1)
# memory usage: 182.7 MB

# %%
df_orders.describe()
# Out:
#            order_id       user_id  order_number     order_dow  \
# count  3.421083e+06  3.421083e+06  3.421083e+06  3.421083e+06
# mean   1.710542e+06  1.029782e+05  1.715486e+01  2.776219e+00
# std    9.875817e+05  5.953372e+04  1.773316e+01  2.046829e+00
# min    1.000000e+00  1.000000e+00  1.000000e+00  0.000000e+00
# 25%    8.552715e+05  5.139400e+04  5.000000e+00  1.000000e+00
# 50%    1.710542e+06  1.026890e+05  1.100000e+01  3.000000e+00
# 75%    2.565812e+06  1.543850e+05  2.300000e+01  5.000000e+00
# max    3.421083e+06  2.062090e+05  1.000000e+02  6.000000e+00
#
#        order_hour_of_day  days_since_prior_order
# count       3.421083e+06            3.214874e+06
# mean        1.345202e+01            1.111484e+01
# std         4.226088e+00            9.206737e+00
# min         0.000000e+00            0.000000e+00
# 25%         1.000000e+01            4.000000e+00
# 50%         1.300000e+01            7.000000e+00
# 75%         1.600000e+01            1.500000e+01
# max         2.300000e+01            3.000000e+01

# %%
pd.options.display.float_format = '{:,.2f}'.format
df_orders.describe()
# Out:
#           order_id      user_id  order_number    order_dow  order_hour_of_day  \
# count 3,421,083.00 3,421,083.00  3,421,083.00 3,421,083.00       3,421,083.00
# mean  1,710,542.00   102,978.21         17.15         2.78              13.45
# std     987,581.74    59,533.72         17.73         2.05               4.23
# min           1.00         1.00          1.00         0.00               0.00
# 25%     855,271.50    51,394.00          5.00         1.00              10.00
# 50%   1,710,542.00   102,689.00         11.00         3.00              13.00
# 75%   2,565,812.50   154,385.00         23.00         5.00              16.00
# max   3,421,083.00   206,209.00        100.00         6.00              23.00
#
#        days_since_prior_order
# count            3,214,874.00
# mean                    11.11
# std                      9.21
# min                      0.00
# 25%                      4.00
# 50%                      7.00
# 75%                     15.00
# max                     30.00

# %%
df_orders.isna().sum()
# Out:
# order_id                       0
# user_id                        0
# eval_set                       0
# order_number                   0
# order_dow                      0
# order_hour_of_day              0
# days_since_prior_order    206209
# dtype: int64

# %%
df_orders["order_id"].nunique()
# Out:
# 3421083

# %%
df_orders["user_id"].nunique()
# Out:
# 206209

# %%
df_orders["eval_set"].value_counts(dropna=False)
# Out:
# eval_set
# prior    3214874
# train     131209
# test       75000
# Name: count, dtype: int64

# %%
df_orders["order_dow"].value_counts().sort_index()
# Out:
# order_dow
# 0    600905
# 1    587478
# 2    467260
# 3    436972
# 4    426339
# 5    453368
# 6    448761
# Name: count, dtype: int64

# %%
df_orders["order_hour_of_day"].value_counts().sort_index()
# Out:
# order_hour_of_day
# 0      22758
# 1      12398
# 2       7539
# 3       5474
# 4       5527
# 5       9569
# 6      30529
# 7      91868
# 8     178201
# 9     257812
# 10    288418
# 11    284728
# 12    272841
# 13    277999
# 14    283042
# 15    283639
# 16    272553
# 17    228795
# 18    182912
# 19    140569
# 20    104292
# 21     78109
# 22     61468
# 23     40043
# Name: count, dtype: int64

# %%
df_orders["days_since_prior_order"].isna().sum()
# Out:
# np.int64(206209)

# %%
df_orders.loc[df_orders["order_number"] == 1, "days_since_prior_order"].isna().all()
# Out:
# np.True_

# %%
df_orders["order_id"].is_unique
# Out:
# True

# %%
df_orders["order_dow"].between(0, 6).all()
# Out:
# np.True_

# %%
df_orders["order_hour_of_day"].between(0, 23).all()
# Out:
# np.True_

# %%
df_orders_train = df_orders[df_orders["eval_set"] == "train"]
df_orders_train.head()
# Out:
#     order_id  user_id eval_set  order_number  order_dow  order_hour_of_day  \
# 10   1187899        1    train            11          4                  8
# 25   1492625        2    train            15          1                 11
# 49   2196797        5    train             5          0                 11
# 74    525192        7    train            21          2                 11
# 78    880375        8    train             4          1                 14
#
#     days_since_prior_order
# 10                   14.00
# 25                   30.00
# 49                    6.00
# 74                    6.00
# 78                   10.00

# %%
df_orders_train.drop(columns=["eval_set"])
df_orders_train.head()
# Out:
#     order_id  user_id eval_set  order_number  order_dow  order_hour_of_day  \
# 10   1187899        1    train            11          4                  8
# 25   1492625        2    train            15          1                 11
# 49   2196797        5    train             5          0                 11
# 74    525192        7    train            21          2                 11
# 78    880375        8    train             4          1                 14
#
#     days_since_prior_order
# 10                   14.00
# 25                   30.00
# 49                    6.00
# 74                    6.00
# 78                   10.00

# %%
del df_orders

# %%
df_orders_products_train.head()
# Out:
#    order_id  product_id  add_to_cart_order  reordered
# 0         1       49302                  1          1
# 1         1       11109                  2          1
# 2         1       10246                  3          0
# 3         1       49683                  4          0
# 4         1       43633                  5          1

# %%
df_orders_products_train.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 1384617 entries, 0 to 1384616
# Data columns (total 4 columns):
#  #   Column             Non-Null Count    Dtype
# ---  ------             --------------    -----
#  0   order_id           1384617 non-null  int64
#  1   product_id         1384617 non-null  int64
#  2   add_to_cart_order  1384617 non-null  int64
#  3   reordered          1384617 non-null  int64
# dtypes: int64(4)
# memory usage: 42.3 MB

# %%
df_orders_products_train.dtypes
# Out:
# order_id             int64
# product_id           int64
# add_to_cart_order    int64
# reordered            int64
# dtype: object

# %%
df_orders_products_train.describe()
# Out:
#           order_id   product_id  add_to_cart_order    reordered
# count 1,384,617.00 1,384,617.00       1,384,617.00 1,384,617.00
# mean  1,706,297.62    25,556.24               8.76         0.60
# std     989,732.65    14,121.27               7.42         0.49
# min           1.00         1.00               1.00         0.00
# 25%     843,370.00    13,380.00               3.00         0.00
# 50%   1,701,880.00    25,298.00               7.00         1.00
# 75%   2,568,023.00    37,940.00              12.00         1.00
# max   3,421,070.00    49,688.00              80.00         1.00

# %%
df_orders_products_train.isna().sum()
# Out:
# order_id             0
# product_id           0
# add_to_cart_order    0
# reordered            0
# dtype: int64

# %%
len(df_orders_products_train)
# Out:
# 1384617

# %%
df_orders_products_train["order_id"].nunique()
# Out:
# 131209

# %%
df_orders_products_train["product_id"].nunique()
# Out:
# 39123

# %%
df_orders_products_train["reordered"].value_counts(dropna=False)
# Out:
# reordered
# 1    828824
# 0    555793
# Name: count, dtype: int64

# %%
df_orders_products_train["reordered"].value_counts(normalize=True)
# Out:
# reordered
# 1   0.60
# 0   0.40
# Name: proportion, dtype: float64

# %%
df_orders_products_train["add_to_cart_order"].describe()
# Out:
# count   1,384,617.00
# mean            8.76
# std             7.42
# min             1.00
# 25%             3.00
# 50%             7.00
# 75%            12.00
# max            80.00
# Name: add_to_cart_order, dtype: float64

# %%
df_orders_products_train["add_to_cart_order"].value_counts().sort_index().head(20)
# Out:
# add_to_cart_order
# 1     131209
# 2     124364
# 3     116996
# 4     108963
# 5     100745
# 6      91850
# 7      83142
# 8      74601
# 9      66618
# 10     59401
# 11     52848
# 12     46814
# 13     41431
# 14     36588
# 15     32194
# 16     28363
# 17     24841
# 18     21733
# 19     19014
# 20     16541
# Name: count, dtype: int64

# %%
df_orders_products_train["order_id"].is_unique
# Out:
# False

# %%
df_orders_products_train["product_id"].is_unique
# Out:
# False

# %%
df_orders_products_train["reordered"].isin([0, 1]).all()
# Out:
# np.True_

# %%
(df_orders_products_train["add_to_cart_order"] > 0).all()
# Out:
# np.True_

# %%
df_orders_products_train[["order_id", "product_id"]].isna().sum()
# Out:
# order_id      0
# product_id    0
# dtype: int64

# %%
df_products.head()
# Out:
#    product_id                                       product_name  aisle_id  \
# 0           1                         Chocolate Sandwich Cookies        61
# 1           2                                   All-Seasons Salt       104
# 2           3               Robust Golden Unsweetened Oolong Tea        94
# 3           4  Smart Ones Classic Favorites Mini Rigatoni Wit...        38
# 4           5                          Green Chile Anytime Sauce         5
#
#    department_id  prices
# 0             19    5.80
# 1             13    9.30
# 2              7    4.50
# 3              1   10.50
# 4             13    4.30

# %%
df_products.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 49693 entries, 0 to 49692
# Data columns (total 5 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   product_id     49693 non-null  int64
#  1   product_name   49677 non-null  str
#  2   aisle_id       49693 non-null  int64
#  3   department_id  49693 non-null  int64
#  4   prices         49693 non-null  float64
# dtypes: float64(1), int64(3), str(1)
# memory usage: 1.9 MB

# %%
df_products.dtypes
# Out:
# product_id         int64
# product_name         str
# aisle_id           int64
# department_id      int64
# prices           float64
# dtype: object

# %%
df_products.describe()
# Out:
#        product_id  aisle_id  department_id    prices
# count   49,693.00 49,693.00      49,693.00 49,693.00
# mean    24,844.35     67.77          11.73      9.99
# std     14,343.72     38.32           5.85    453.52
# min          1.00      1.00           1.00      1.00
# 25%     12,423.00     35.00           7.00      4.10
# 50%     24,845.00     69.00          13.00      7.10
# 75%     37,265.00    100.00          17.00     11.20
# max     49,688.00    134.00          21.00 99,999.00

# %%
df_products.isna().sum()
# Out:
# product_id        0
# product_name     16
# aisle_id          0
# department_id     0
# prices            0
# dtype: int64

# %%
df_products["product_id"].nunique()
# Out:
# 49686

# %%
df_products["product_id"].is_unique
# Out:
# False

# %%
df_products["department_id"].nunique()
# Out:
# 21

# %%
df_products["aisle_id"].nunique()
# Out:
# 134

# %%
df_products["product_name"].duplicated().sum()
# Out:
# np.int64(20)

# %%
df_products[["product_id", "product_name", "aisle_id", "department_id"]].head()
# Out:
#    product_id                                       product_name  aisle_id  \
# 0           1                         Chocolate Sandwich Cookies        61
# 1           2                                   All-Seasons Salt       104
# 2           3               Robust Golden Unsweetened Oolong Tea        94
# 3           4  Smart Ones Classic Favorites Mini Rigatoni Wit...        38
# 4           5                          Green Chile Anytime Sauce         5
#
#    department_id
# 0             19
# 1             13
# 2              7
# 3              1
# 4             13

# %%
df_products["product_id"].is_unique
# Out:
# False

# %%
df_products["department_id"].isna().sum()
# Out:
# np.int64(0)

# %%
df_products["aisle_id"].isna().sum()
# Out:
# np.int64(0)

# %%
df_departments.head()
# Out:
#    department_id  department_id.1 department
# 0              0                0     frozen
# 1              1                1      other
# 2              2                2     bakery
# 3              3                3    produce
# 4              4                4    alcohol

# %%
df_departments.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 21 entries, 0 to 20
# Data columns (total 3 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   department_id    21 non-null     int64
#  1   department_id.1  21 non-null     int64
#  2   department       21 non-null     str
# dtypes: int64(2), str(1)
# memory usage: 636.0 bytes

# %%
df_departments.dtypes
# Out:
# department_id      int64
# department_id.1    int64
# department           str
# dtype: object

# %%
df_departments.isna().sum()
# Out:
# department_id      0
# department_id.1    0
# department         0
# dtype: int64

# %%
df_departments["department"].nunique()
# Out:
# 21

# %%
df_departments["department_id"].is_unique
# Out:
# True

# %%
df_departments.isna().sum()
# Out:
# department_id      0
# department_id.1    0
# department         0
# dtype: int64

# %%
df_aisles.head()
# Out:
#    aisle_id                       aisle
# 0         1       prepared soups salads
# 1         2           specialty cheeses
# 2         3         energy granola bars
# 3         4               instant foods
# 4         5  marinades meat preparation

# %%
df_aisles.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 134 entries, 0 to 133
# Data columns (total 2 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   aisle_id  134 non-null    int64
#  1   aisle     134 non-null    str
# dtypes: int64(1), str(1)
# memory usage: 2.2 KB

# %%
df_aisles.dtypes
# Out:
# aisle_id    int64
# aisle         str
# dtype: object

# %%
df_aisles["aisle"].nunique()
# Out:
# 134

# %%
df_aisles["aisle_id"].is_unique
# Out:
# True

# %%
df_aisles.isna().sum()
# Out:
# aisle_id    0
# aisle       0
# dtype: int64

# %%
df_merged = pd.merge(df_products, df_departments, on="department_id", how="left")

# %%
df_merged.head()
# Out:
#    product_id                                       product_name  aisle_id  \
# 0           1                         Chocolate Sandwich Cookies        61
# 1           2                                   All-Seasons Salt       104
# 2           3               Robust Golden Unsweetened Oolong Tea        94
# 3           4  Smart Ones Classic Favorites Mini Rigatoni Wit...        38
# 4           5                          Green Chile Anytime Sauce         5
#
#    department_id  prices  department_id.1 department
# 0             19    5.80            19.00       deli
# 1             13    9.30            13.00  breakfast
# 2              7    4.50             7.00       pets
# 3              1   10.50             1.00      other
# 4             13    4.30            13.00  breakfast

# %%
pd.merge(
    df_products,
    df_departments,
    on="department_id",
    how="inner"
).head()
# Out:
#    product_id                                       product_name  aisle_id  \
# 0           1                         Chocolate Sandwich Cookies        61
# 1           2                                   All-Seasons Salt       104
# 2           3               Robust Golden Unsweetened Oolong Tea        94
# 3           4  Smart Ones Classic Favorites Mini Rigatoni Wit...        38
# 4           5                          Green Chile Anytime Sauce         5
#
#    department_id  prices  department_id.1 department
# 0             19    5.80               19       deli
# 1             13    9.30               13  breakfast
# 2              7    4.50                7       pets
# 3              1   10.50                1      other
# 4             13    4.30               13  breakfast

# %%
pd.merge(
    df_products,
    df_departments,
    on="department_id",
    how="left"
).head()
# Out:
#    product_id                                       product_name  aisle_id  \
# 0           1                         Chocolate Sandwich Cookies        61
# 1           2                                   All-Seasons Salt       104
# 2           3               Robust Golden Unsweetened Oolong Tea        94
# 3           4  Smart Ones Classic Favorites Mini Rigatoni Wit...        38
# 4           5                          Green Chile Anytime Sauce         5
#
#    department_id  prices  department_id.1 department
# 0             19    5.80            19.00       deli
# 1             13    9.30            13.00  breakfast
# 2              7    4.50             7.00       pets
# 3              1   10.50             1.00      other
# 4             13    4.30            13.00  breakfast

# %%
pd.merge(
    df_products,
    df_departments,
    on="department_id",
    how="outer",
    indicator=True
).head()
# Out:
#    product_id                                       product_name  aisle_id  \
# 0         NaN                                                NaN       NaN
# 1        4.00  Smart Ones Classic Favorites Mini Rigatoni Wit...     38.00
# 2        8.00                  Cut Russet Potatoes Steam N' Mash    116.00
# 3       12.00                         Chocolate Fudge Layer Cake    119.00
# 4       18.00                Pizza for One Suprema  Frozen Pizza     79.00
#
#    department_id  prices  department_id.1 department      _merge
# 0              0     NaN             0.00     frozen  right_only
# 1              1   10.50             1.00      other        both
# 2              1    1.10             1.00      other        both
# 3              1    9.40             1.00      other        both
# 4              1   10.60             1.00      other        both

# %%
df_departments = df_departments[df_departments['department_id'] != 0]

# %%
df_merged = pd.merge(df_products, df_departments, on="department_id", how="outer")
df_merged.head()
# Out:
#    product_id                                       product_name  aisle_id  \
# 0           4  Smart Ones Classic Favorites Mini Rigatoni Wit...        38
# 1           8                  Cut Russet Potatoes Steam N' Mash       116
# 2          12                         Chocolate Fudge Layer Cake       119
# 3          18                Pizza for One Suprema  Frozen Pizza        79
# 4          30         Three Cheese Ziti, Marinara with Meatballs        38
#
#    department_id  prices  department_id.1 department
# 0              1   10.50             1.00      other
# 1              1    1.10             1.00      other
# 2              1    9.40             1.00      other
# 3              1   10.60             1.00      other
# 4              1   13.80             1.00      other

# %%
df_products_departments = pd.merge(
    df_products,
    df_departments,
    on="department_id",
    how="left"
)

df_products_departments.head()
# Out:
#    product_id                                       product_name  aisle_id  \
# 0           1                         Chocolate Sandwich Cookies        61
# 1           2                                   All-Seasons Salt       104
# 2           3               Robust Golden Unsweetened Oolong Tea        94
# 3           4  Smart Ones Classic Favorites Mini Rigatoni Wit...        38
# 4           5                          Green Chile Anytime Sauce         5
#
#    department_id  prices  department_id.1 department
# 0             19    5.80            19.00       deli
# 1             13    9.30            13.00  breakfast
# 2              7    4.50             7.00       pets
# 3              1   10.50             1.00      other
# 4             13    4.30            13.00  breakfast

# %%
df_products_departments_check = pd.merge(
    df_products,
    df_departments,
    on="department_id",
    how="left",
    indicator=True
)

df_products_departments_check.head()
# Out:
#    product_id                                       product_name  aisle_id  \
# 0           1                         Chocolate Sandwich Cookies        61
# 1           2                                   All-Seasons Salt       104
# 2           3               Robust Golden Unsweetened Oolong Tea        94
# 3           4  Smart Ones Classic Favorites Mini Rigatoni Wit...        38
# 4           5                          Green Chile Anytime Sauce         5
#
#    department_id  prices  department_id.1 department _merge
# 0             19    5.80            19.00       deli   both
# 1             13    9.30            13.00  breakfast   both
# 2              7    4.50             7.00       pets   both
# 3              1   10.50             1.00      other   both
# 4             13    4.30            13.00  breakfast   both

# %%
df_products_departments_check["_merge"].value_counts()
# Out:
# _merge
# both          48435
# left_only      1258
# right_only        0
# Name: count, dtype: int64

# %%
df_products_departments_check[
    df_products_departments_check["_merge"] == "left_only"
].head()
# Out:
#      product_id                                       product_name  aisle_id  \
# 37           38                    Ultra Antibacterial Dish Liquid       100
# 71           72                          Organic Honeycrisp Apples       100
# 109         110                             Uncured Turkey Bologna       100
# 296         297  Write Bros Ball Point Pens, Cap-Pen, Medium (1...       100
# 416         417         Classics Baby Binks Easter Chocolate Bunny       100
#
#      department_id  prices  department_id.1 department     _merge
# 37              21   13.40              NaN        NaN  left_only
# 71              21   10.70              NaN        NaN  left_only
# 109             21    7.60              NaN        NaN  left_only
# 296             21    8.80              NaN        NaN  left_only
# 416             21    2.80              NaN        NaN  left_only

# %%
df_products_departments = pd.merge(
    df_products,
    df_departments,
    on="department_id",
    how="left"
)

df_products_departments.head()
# Out:
#    product_id                                       product_name  aisle_id  \
# 0           1                         Chocolate Sandwich Cookies        61
# 1           2                                   All-Seasons Salt       104
# 2           3               Robust Golden Unsweetened Oolong Tea        94
# 3           4  Smart Ones Classic Favorites Mini Rigatoni Wit...        38
# 4           5                          Green Chile Anytime Sauce         5
#
#    department_id  prices  department_id.1 department
# 0             19    5.80            19.00       deli
# 1             13    9.30            13.00  breakfast
# 2              7    4.50             7.00       pets
# 3              1   10.50             1.00      other
# 4             13    4.30            13.00  breakfast

# %%
df_products_departments["department"].value_counts()
# Out:
# department
# meat seafood       6565
# deli               6264
# breakfast          5371
# pets               4365
# other              4007
# household          3449
# babies             3085
# dairy eggs         2092
# bulk               1858
# alcohol            1684
# produce            1516
# missing            1322
# beverages          1139
# canned goods       1116
# snacks             1081
# international      1056
# dry goods pasta     972
# pantry              907
# bakery              548
# personal care        38
# Name: count, dtype: int64

# %%
df_products_enriched = pd.merge(
    df_products_departments,
    df_aisles,
    on="aisle_id",
    how="left"
)

df_products_enriched.head()
# Out:
#    product_id                                       product_name  aisle_id  \
# 0           1                         Chocolate Sandwich Cookies        61
# 1           2                                   All-Seasons Salt       104
# 2           3               Robust Golden Unsweetened Oolong Tea        94
# 3           4  Smart Ones Classic Favorites Mini Rigatoni Wit...        38
# 4           5                          Green Chile Anytime Sauce         5
#
#    department_id  prices  department_id.1 department  \
# 0             19    5.80            19.00       deli
# 1             13    9.30            13.00  breakfast
# 2              7    4.50             7.00       pets
# 3              1   10.50             1.00      other
# 4             13    4.30            13.00  breakfast
#
#                         aisle
# 0               cookies cakes
# 1           spices seasonings
# 2                         tea
# 3                frozen meals
# 4  marinades meat preparation

# %%
df_products_aisles_check = pd.merge(
    df_products_departments,
    df_aisles,
    on="aisle_id",
    how="left",
    indicator=True
)

df_products_aisles_check["_merge"].value_counts()
# Out:
# _merge
# both          49693
# left_only         0
# right_only        0
# Name: count, dtype: int64

# %%
df_products_aisles_check[
    df_products_aisles_check["_merge"] == "left_only"
].head()
# Out:
# Empty DataFrame
# Columns: [product_id, product_name, aisle_id, department_id, prices, department_id.1, department, aisle, _merge]
# Index: []

# %%
print(df_products.shape)
print(df_products_departments.shape)
print(df_products_enriched.shape)
# Out:
# (49693, 5)
# (49693, 7)
# (49693, 8)

# %%
df_departments["department_id"].is_unique
# Out:
# True

# %%
df_aisles["aisle_id"].is_unique
# Out:
# True

# %%
df_products_enriched["aisle"].value_counts().head(10)
# Out:
# aisle
# missing                 1258
# candy chocolate         1246
# ice cream ice           1091
# vitamins supplements    1038
# yogurt                  1026
# chips pretzels           989
# beverages                    0  ...        0    0                       0
# breakfast                    0  ...      493    0                       0
# bulk                         0  ...        0    0                       0
# canned goods                 0  ...        0    0                       0
# dairy eggs                   0  ...        0    0                       0
# deli                         0  ...        0    0                       0
# dry goods pasta              0  ...        0    0                       0
# household                    0  ...        0    0                       0
# international              387  ...        0    0                       0
# meat seafood                 0  ...        0    0                       0
# missing                      0  ...        0    0                     159
# other                        0  ...        0    0                       0
# pantry                       0  ...        0    0                       0
# personal care                0  ...        0    0                       0
# pets                         0  ...        0  894                       0
# produce                      0  ...        0    0                       0
# snacks                       0  ...        0    0                       0
#
# aisle            tortillas flat bread  trail mix snack mix  trash bags liners  \
# department
# alcohol                             0                    0                  0
# babies                              0                    0                112
# bakery                              0                    0                  0
# beverages                           0                    0                  0
# breakfast                           0                    0                  0
# bulk                                0                    0                  0
# canned goods                        0                    0                  0
# dairy eggs                          0                    0                  0
# deli                                0                   69                  0
# dry goods pasta                     0                    0                  0
# household                           0                    0                  0
# international                       0                    0                  0
# meat seafood                        0                    0                  0
# missing                             0                    0                  0
# other                               0                    0                  0
# pantry                              0                    0                  0
# personal care                       0                    0                  0
# pets                                0                    0                  0
# produce                           241                    0                  0
# snacks                              0                    0                  0
#
# aisle            vitamins supplements  water seltzer sparkling water  \
# department
# alcohol                             0                              0
# babies                              0                              0
# bakery                              0                              0
# beverages                           0                              0
# breakfast                           0                              0
# bulk                                0                              0
# canned goods                        0                              0
# dairy eggs                          0                              0
# deli                                0                              0
# dry goods pasta                     0                              0
# household                           0                              0
# international                       0                              0
# meat seafood                     1038                              0
# missing                             0                              0
# other                               0                              0
# pantry                              0                              0
# personal care                       0                              0
# pets                                0                            344
# produce                             0                              0
# snacks                              0                              0
#
# aisle            white wines  yogurt
# department
# alcohol                    0       0
# babies                     0       0
# bakery                     0       0
# beverages                  0       0
# breakfast                  0       0
# bulk                       0       0
# canned goods               0       0
# dairy eggs                 0       0
# deli                       0       0
# dry goods pasta            0       0
# household                  0    1026
# international            147       0
# meat seafood               0       0
# missing                    0       0
# other                      0       0
# pantry                     0       0
# personal care              0       0
# pets                       0       0
# produce                    0       0
# snacks                     0       0
#
# [20 rows x 133 columns]

# %%
print(df_departments.head(5))
# Out:
#    department_id  department_id.1     department
# 1              1                1          other
# 2              2                2         bakery
# 3              3                3        produce
# 4              4                4        alcohol
# 5              5                5  international

# %%
df_departments = pd.read_csv('../data/processed/departments_t.csv')

# %%
print(df_departments.head(5))
# Out:
#    department_id  department_id.1 department
# 0              0                0     frozen
# 1              1                1      other
# 2              2                2     bakery
# 3              3                3    produce
# 4              4                4    alcohol

# %%
import pandas as pd

# %%
df_departments['department_id'] = df_departments['department_id'] + 1

# %%
print(df_departments.head())
# Out:
#    department_id  department_id.1 department
# 0              1                0     frozen
# 1              2                1      other
# 2              3                2     bakery
# 3              4                3    produce
# 4              5                4    alcohol

# %%
df_products_departments = pd.merge(
    df_products, 
    df_departments, 
    on="department_id", 
    how="left"
)

# %%
df_products_enriched = pd.merge(
    df_products_departments, 
    df_aisles, 
    on="aisle_id", 
    how="left"
)

# %%
df_products_enriched.head()
# Out:
#    product_id                                       product_name  aisle_id  \
# 0           1                         Chocolate Sandwich Cookies        61
# 1           2                                   All-Seasons Salt       104
# 2           3               Robust Golden Unsweetened Oolong Tea        94
# 3           4  Smart Ones Classic Favorites Mini Rigatoni Wit...        38
# 4           5                          Green Chile Anytime Sauce         5
#
#    department_
# bakery                            241                    0                  0
# beverages                           0                    0                  0
# breakfast                           0                    0                  0
# bulk                                0                    0                  0
# canned goods                        0                    0                  0
# dairy eggs                          0                    0                  0
# deli                                0                    0                  0
# dry goods pasta                     0                    0                  0
# frozen                              0                    0                  0
# household                           0                    0                112
# international                       0                    0                  0
# meat seafood                        0                    0                  0
# missing                             0                    0                  0
# other                               0                    0                  0
# pantry                              0                    0                  0
# personal care                       0                    0                  0
# pets                                0                    0                  0
# produce                             0                    0                  0
# snacks                              0                   69                  0
#
# aisle            vitamins supplements  water seltzer sparkling water  \
# department
# alcohol                             0                              0
# babies                              0                              0
# bakery                              0                              0
# beverages                           0                            344
# breakfast                           0                              0
# bulk                                0                              0
# canned goods                        0                              0
# dairy eggs                          0                              0
# deli                                0                              0
# dry goods pasta                     0                              0
# frozen                              0                              0
# household                           0                              0
# international                       0                              0
# meat seafood                        0                              0
# missing                             0                              0
# other                               0                              0
# pantry                              0                              0
# personal care                    1038                              0
# pets                                0                              0
# produce                             0                              0
# snacks                              0                              0
#
# aisle            white wines  yogurt
# department
# alcohol                  147       0
# babies                     0       0
# bakery                     0       0
# beverages                  0       0
# breakfast                  0       0
# bulk                       0       0
# canned goods               0       0
# dairy eggs                 0    1026
# deli                       0       0
# dry goods pasta            0       0
# frozen                     0       0
# household                  0       0
# international              0       0
# meat seafood               0       0
# missing                    0       0
# other                      0       0
# pantry                     0       0
# personal care              0       0
# pets                       0       0
# produce                    0       0
# snacks                     0       0
#
# [21 rows x 134 columns]

# %%
df_train_transactions = pd.merge(
    df_orders_train,
    df_orders_products_train,
    on="order_id",
    how="left"
)

df_train_transactions.head()
# Out:
#    order_id  user_id eval_set  order_number  order_dow  order_hour_of_day  \
# 0   1187899        1    train            11          4                  8
# 1   1187899        1    train            11          4                  8
# 2   1187899        1    train            11          4                  8
# 3   1187899        1    train            11          4                  8
# 4   1187899        1    train            11          4                  8
#
#    days_since_prior_order  product_id  add_to_cart_order  reordered
# 0                   14.00         196                  1          1
# 1                   14.00       25133                  2          1
# 2                   14.00       38928                  3          1
# 3                   14.00       26405                  4          1
# 4                   14.00       39657                  5          1

# %%
df_train_transactions_check = pd.merge(
    df_orders_train,
    df_orders_products_train,
    on="order_id",
    how="left",
    indicator=True
)

df_train_transactions_check.head()
# Out:
#    order_id  user_id eval_set  order_number  order_dow  order_hour_of_day  \
# 0   1187899        1    train            11          4                  8
# 1   1187899        1    train            11          4                  8
# 2   1187899        1    train            11          4                  8
# 3   1187899        1    train            11          4                  8
# 4   1187899        1    train            11          4                  8
#
#    days_since_prior_order  product_id  add_to_cart_order  reordered _merge
# 0                   14.00         196                  1          1   both
# 1                   14.00       25133                  2          1   both
# 2                   14.00       38928                  3          1   both
# 3                   14.00       26405                  4          1   both
# 4                   14.00       39657                  5          1   both

# %%
df_train_transactions_check["_merge"].value_counts()
# Out:
# _merge
# both          1384617
# left_only           0
# right_only          0
# Name: count, dtype: int64

# %%
df_train_transactions_check[
    df_train_transactions_check["_merge"] == "left_only"
].head()
# Out:
# Empty DataFrame
# Columns: [order_id, user_id, eval_set, order_number, order_dow, order_hour_of_day, days_since_prior_order, product_id, add_to_cart_order, reordered, _merge]
# Index: []

# %%
print(df_orders_train.shape)
print(df_orders_products_train.shape)
print(df_train_transactions.shape)
# Out:
# (131209, 7)
# (1384617, 4)
# (1384617, 10)

# %%
df_train_transactions.columns
# Out:
# Index(['order_id', 'user_id', 'eval_set', 'order_number', 'order_dow',
#        'order_hour_of_day', 'days_since_prior_order', 'product_id',
#        'add_to_cart_order', 'reordered'],
#       dtype='str')

# %%
df_train_transactions.groupby("order_id").size().head()
# Out:
# order_id
# 1      8
# 36     8
# 38     9
# 96     7
# 98    49
# dtype: int64

# %%
df_train_transactions.groupby("order_id").size().describe()
# Out:
# count   131,209.00
# mean         10.55
# std           7.93
# min           1.00
# 25%           5.00
# 50%           9.00
# 75%          14.00
# max          80.00
# dtype: float64

# %%
df_train_transactions.groupby("order_dow").size() / df_train_transactions["order_id"].nunique()
# Out:
# order_dow
# 0   2.47
# 1   1.57
# 2   1.22
# 3   1.18
# 4   1.18
# 5   1.35
# 6   1.58
# dtype: float64

# %%
basket_size_by_order = (
    df_train_transactions
    .groupby(["order_id", "order_dow"])
    .size()
    .reset_index(name="basket_size")
)

basket_size_by_order.groupby("order_dow")["basket_size"].mean()
# Out:
# order_dow
# 0   11.80
# 1   10.47
# 2    9.96
# 3    9.84
# 4    9.74
# 5   10.16
# 6   10.97
# Name: basket_size, dtype: float64

# %%
df_train_transactions.groupby("order_hour_of_day")["reordered"].mean()
# Out:
# order_hour_of_day
# 0    0.57
# 1    0.58
# 2    0.58
# 3    0.58
# 4    0.60
# 5    0.62
# 6    0.65
# 7    0.65
# 8    0.64
# 9    0.62
# 10   0.61
# 11   0.59
# 12   0.59
# 13   0.59
# 14   0.59
# 15   0.58
# 16   0.59
# 17   0.59
# 18   0.58
# 19   0.59
# 20   0.60
# 21   0.61
# 22   0.60
# 23   0.59
# Name: reordered, dtype: float64

# %%
df_train_transactions["product_id"].isna().sum()
# Out:
# np.int64(0)

# %%
df_train_transactions["user_id"].isna().sum()
# Out:
# np.int64(0)

# %%
df_train_transactions["order_id"].value_counts().head()
# Out:
# order_id
# 2813632    80
# 1395075    80
# 949182     77
# 2869702    76
# 341238     76
# Name: count, dtype: int64

# %%
df_train_analytic = pd.merge(
    df_train_transactions,
    df_products_enriched,
    on="product_id",
    how="left"
)

df_train_analytic.head()
# Out:
#    order_id  user_id eval_set  order_number  order_dow  order_hour_of_day  \
# 0   1187899        1    train            11          4                  8
# 1   1187899        1    train            11          4                  8
# 2   1187899        1    train            11          4                  8
# 3   1187899        1    train            11          4                  8
# 4   1187899        1    train            11          4                  8
#
#    days_since_prior_order  product_id  add_to_cart_order  reordered  \
# 0                   14.00         196                  1          1
# 1                   14.00       25133                  2          1
# 2                   14.00       38928                  3          1
# 3                   14.00       26405                  4          1
# 4                   14.00       39657                  5          1
#
#                        product_name  aisle_id  department_id  prices  \
# 0                              Soda     77.00           7.00    9.00
# 1             Organic String Cheese     21.00          16.00    8.60
# 2          0% Greek Strained Yogurt    120.00          16.00   12.60
# 3  XL Pick-A-Size Paper Towel Rolls     54.00          17.00    1.00
# 4            Milk Chocolate Almonds     45.00          19.00    6.80
#
#    department_id.1  department            aisle
# 0             6.00   beverages      soft drinks
# 1            15.00  dairy eggs  packaged cheese
# 2            15.00  dairy eggs           yogurt
# 3            16.00   household      paper goods
# 4            18.00      snacks  candy chocolate

# %%
df_train_analytic_check = pd.merge(
    df_train_transactions,
    df_products_enriched,
    on="product_id",
    how="left",
    indicator=True
)

df_train_analytic_check["_merge"].value_counts()
# Out:
# _merge
# both          1384618
# left_only          88
# right_only          0
# Name: count, dtype: int64

# %%
df_train_analytic_check[
    df_train_analytic_check["_merge"] == "left_only"
].head()
# Out:
#        order_id  user_id eval_set  order_number  order_dow  order_hour_of_day  \
# 10780   3009052     1629    train            37          0                 13
# 52822    195363     7955    train            12          6                 14
# 59749    831974     9000    train            11          3                 13
# 64159    206208     9640    train            16          6                 11
# 81585    472316    12168    train            10          4                 12
#
#        days_since_prior_order  product_id  add_to_cart_order  reordered  \
# 10780                    3.00        6799                 24          1
# 52822                    8.00        6799                  4          1
# 59749                   20.00        6799                 19          0
# 64159                   12.00        6799                  6          1
# 81585                    0.00        6799                 12          1
#
#       product_name  aisle_id  department_id  prices  department_id.1  \
# 10780          NaN       NaN            NaN     NaN              NaN
# 52822          NaN       NaN            NaN     NaN              NaN
# 59749          NaN       NaN            NaN     NaN              NaN
# 64159          NaN       NaN            NaN     NaN              NaN
# 81585          NaN       NaN            NaN     NaN              NaN
#
#       department aisle     _merge
# 10780        NaN   NaN  left_only
# 52822        NaN   NaN  left_only
# 59749        NaN   NaN  left_only
# 64159        NaN   NaN  left_only
# 81585        NaN   NaN  left_only

# %%
df_train_analytic["product_name"].value_counts().head(10)
# Out:
# product_name
# Banana                    18726
# Bag of Organic Bananas    15480
# Organic Strawberries      10894
# Organic Baby Spinach       9784
# Large Lemon                8135
# Organic Avocado            7409
# Organic Hass Avocado       7293
# Strawberries               6494
# Limes                      6033
# Organic Raspberries        5546
# Name: count, dtype: int64

# %%
df_train_analytic["department"].value_counts()
# Out:
# department
# produce            409087
# dairy eggs         217051
# snacks             118862
# beverages          113962
# frozen             100426
# pantry              81242
# bakery              48394
# canned goods        46799
# deli                44291
# dry goods pasta     38713
# household           35986
# meat seafood        30307
# breakfast           29552
# personal care       21599
# babies              14941
# international       11902
# missing              8251
# alcohol              5602
# pets                 4497
# other                1795
# bulk                 1359
# Name: count, dtype: int64

# %%
df_train_analytic.groupby("department")["reordered"].mean().sort_values(ascending=False)
# Out:
# department
# dairy eggs        0.67
# produce           0.66
# beverages         0.66
# bakery            0.63
# pets              0.63
# deli              0.62
# alcohol           0.61
# meat seafood      0.59
# snacks            0.58
# bulk              0.58
# breakfast         0.57
# frozen            0.56
# babies            0.54
# dry goods pasta   0.49
# canned goods      0.49
# household         0.43
# other             0.39
# missing           0.38
# international     0.38
# pantry            0.36
# personal care     0.34
# Name: reordered, dtype: float64

# %%
pd.crosstab(
    df_train_analytic["department"],
    df_train_analytic["reordered"]
)
# Out:
# reordered             0       1
# department
# alcohol            2203    3399
# babies             6857    8084
# bakery            17702   30692
# beverages         38960   75002
# breakfast         12654   16898
# bulk                573     786
# canned goods      24017   22782
# dairy eggs        70549  146502
# deli              16924   27367
# dry goods pasta   19828   18885
# frozen            44258   56168
# household         20614   15372
# international      7380    4522
# meat seafood      12400   17907
# missing            5103    3148
# other              1098     697
# pantry            51744   29498
# personal care     14309    7290
# pets               1663    2834
# produce          137201  271886
# snacks            49760   69102

# %%
pd.crosstab(
    df_train_analytic["order_dow"],
    df_train_analytic["reordered"],
    normalize="index"
)
# Out:
# reordered    0    1
# order_dow
# 0         0.39 0.61
# 1         0.40 0.60
# 2         0.41 0.59
# 3         0.41 0.59
# 4         0.41 0.59
# 5         0.39 0.61
# 6         0.41 0.59
